# %%
#TASK 1:
#ques 1.1
#Load StarWars csv file

starwars_p='StarWars.csv'

# %%
#installing pandas package

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#reading the datafile(.csv) and assigning it to the variable-StarWars;encoding used as strings are unicoded, so to decode them and producing a string suitable in python as unicode literal

StarWars = pd.read_csv(starwars_p,sep=',', decimal='.', header=1,names=['Respondant ID', 'seen_any_of_6films','fan?',
                                                                        'Episode_1','Episode_2','Episode_3',
                                                                        'Episode_4','Episode_5','Episode_6',
                                                                        'rank_1','rank_2','rank_3','rank_4','rank_5',
                                                                        'rank_6','Han Solo favored?','Luke Skywalker favored?',
                                                                        'Princess Leia Organa favored?',
                                                                        'Anakin Skywalker favored?','Obi Wan Kenobi favored?',
                                                                        'Emperor Palpatine favored?','Darth Vader favored?',
                                                                        'Lando Calrissian favored?','Boba Fett favored?',
                                                                        'C-3P0 favored?','R2 D2 favored?',
                                                                        'Jar Jar Binks favored?','Padme Amidala favored?',
                                                                        'Yoda favored?','shoted_first',
                                                                        'familiar_with_the_Expanded_Universe?',
                                                                        'fan of the_Expanded_Universe?','fan of star_treck?',
                                                                        'Gender','Age','Income','Education','Location'],
                                                                        encoding='unicode_escape')

# %%
#display StarWars file

StarWars
# Out:
#       Respondant ID seen_any_of_6films fan?  \
# 0        3292879998                Yes  Yes
# 1        3292879538                 No  NaN
# 2        3292765271                Yes   No
# 3        3292763116                Yes  Yes
# 4        3292731220                Yes  Yes
# ...             ...                ...  ...
# 1181     3288388730                Yes  Yes
# 1182     3288378779                Yes  Yes
# 1183     3288375286                 No  NaN
# 1184     3288373068                Yes  Yes
# 1185     3288372923                Yes   No
#
#                                      Episode_1  \
# 0     Star Wars: Episode I  The Phantom Menace
# 1                                          NaN
# 2     Star Wars: Episode I  The Phantom Menace
# 3     Star Wars: Episode I  The Phantom Menace
# 4     Star Wars: Episode I  The Phantom Menace
# ...                                        ...
# 1181  Star Wars: Episode I  The Phantom Menace
# 1182  Star Wars: Episode I  The Phantom Menace
# 1183                                       NaN
# 1184  Star Wars: Episode I  The Phantom Menace
# 1185  Star Wars: Episode I  The Phantom Menace
#
#                                         Episode_2  \
# 0     Star Wars: Episode II  Attack of the Clones
# 1                                             NaN
# 2     Star Wars: Episode II  Attack of the Clones
# 3     Star Wars: Episode II  Attack of the Clones
# 4     Star Wars: Episode II  Attack of the Clones
# ...                                           ...
# 1181  Star Wars: Episode II  Attack of the Clones
# 1182  Star Wars: Episode II  Attack of the Clones
# 1183                                          NaN
# 1184  Star Wars: Episode II  Attack of the Clones
# 1185  Star Wars: Episode II  Attack of the Clones
#
#                                         Episode_3  \
# 0     Star Wars: Episode III  Revenge of the Sith
# 1                                             NaN
# 2     Star Wars: Episode III  Revenge of the Sith
# 3     Star Wars: Episode III  Revenge of the Sith
# 4     Star Wars: Episode III  Revenge of the Sith
# ...                                           ...
# 1181  Star Wars: Episode III  Revenge of the Sith
# 1182  Star Wars: Episode III  Revenge of the Sith
# 1183                                          NaN
# 1184  Star Wars: Episode III  Revenge of the Sith
# 1185                                          NaN
#
#                               Episode_4  \
# 0     Star Wars: Episode IV  A New Hope
# 1                                   NaN
# 2                                   NaN
# 3     Star Wars: Episode IV  A New Hope
# 4     Star Wars: Episode IV  A New Hope
# ...                                 ...
# 1181  Star Wars: Episode IV  A New Hope
# 1182  Star Wars: Episode IV  A New Hope
# 1183                                NaN
# 1184  Star Wars: Episode IV  A New Hope
# 1185                                NaN
#
#                                          Episode_5  \
# 0     Star Wars: Episode V The Empire Strikes Back
# 1                                              NaN
# 2                                              NaN
# 3     Star Wars: Episode V The Empire Strikes Back
# 4     Star Wars: Episode V The Empire Strikes Back
# ...                                            ...
# 1181  Star Wars: Episode V The Empire Strikes Back
# 1182  Star Wars: Episode V The Empire Strikes Back
# 1183                                           NaN
# 1184  Star Wars: Episode V The Empire Strikes Back
# 1185  Star Wars: Episode V The Empire Strikes Back
#
#                                      Episode_6  rank_1  ...  \
# 0     Star Wars: Episode VI Return of the Jedi     3.0  ...
# 1                                          NaN     NaN  ...
# 2                                          NaN     1.0  ...
# 3     Star Wars: Episode VI Return of the Jedi     5.0  ...
# 4     Star Wars: Episode VI Return of the Jedi     5.0  ...
# ...                                        ...     ...  ...
# 1181  Star Wars: Episode VI Return of the Jedi     5.0  ...
# 1182  Star Wars: Episode VI Return of the Jedi     4.0  ...
# 1183                                       NaN     NaN  ...
# 1184  Star Wars: Episode VI Return of the Jedi     4.0  ...
# 1185  Star Wars: Episode VI Return of the Jedi     6.0  ...
#
#            Yoda favored?                      shoted_first  \
# 0         Very favorably  I don't understand this question
# 1                    NaN                               NaN
# 2       Unfamiliar (N/A)  I don't understand this question
# 3         Very favorably  I don't understand this question
# 4     Somewhat favorably                            Greedo
# ...                  ...                               ...
# 1181      Very favorably                               Han
# 1182      Very favorably  I don't understand this question
# 1183                 NaN                               NaN
# 1184      Very favorably                               Han
# 1185    Very unfavorably  I don't understand this question
#
#       familiar_with_the_Expanded_Universe?  fan of the_Expanded_Universe?  \
# 0                                      Yes                             No
# 1                                      NaN                            NaN
# 2                                       No                            NaN
# 3                                       No                            NaN
# 4                                      Yes                             No
# ...                                    ...                            ...
# 1181                                    No                            NaN
# 1182                                    No                            NaN
# 1183                                   NaN                            NaN
# 1184                                    No                            NaN
# 1185                                    No                            NaN
#
#       fan of star_treck?  Gender    Age               Income  \
# 0                     No    Male  18-29                  NaN
# 1                    Yes    Male  18-29         $0 - $24,999
# 2                     No    Male  18-29         $0 - $24,999
# 3                    Yes    Male  18-29  $100,000 - $149,999
# 4                     No    Male  18-29  $100,000 - $149,999
# ...                  ...     ...    ...                  ...
# 1181                 Yes  Female  18-29         $0 - $24,999
# 1182                 Yes  Female  30-44    $50,000 - $99,999
# 1183                  No  Female  30-44    $50,000 - $99,999
# 1184                 Yes  Female  45-60  $100,000 - $149,999
# 1185                  No  Female   > 60    $50,000 - $99,999
#
#                              Education            Location
# 0                   High school degree      South Atlantic
# 1                      Bachelor degree  West South Central
# 2                   High school degree  West North Central
# 3     Some college or Associate degree  West North Central
# 4     Some college or Associate degree  West North Central
# ...                                ...                 ...
# 1181  Some college or Associate degree  East North Central
# 1182                   Bachelor degree            Mountain
# 1183                   Bachelor degree     Middle Atlantic
# 1184  Some college or Associate degree  East North Central
# 1185                   Graduate degree             Pacific
#
# [1186 rows x 38 columns]

# %%
#drop first and second row as it has redundant data

StarWars=StarWars.drop(StarWars.index[0])
StarWars=StarWars.drop(StarWars.index[0])

# %%
#resetting index(starting from 0) and assigning it to starwars itself

StarWars=StarWars.reset_index(drop=True)

# %%
#display updated StarWars file

StarWars
# Out:
#       Respondant ID seen_any_of_6films fan?  \
# 0        3292765271                Yes   No
# 1        3292763116                Yes  Yes
# 2        3292731220                Yes  Yes
# 3        3292719380                Yes  Yes
# 4        3292684787                Yes  Yes
# ...             ...                ...  ...
# 1179     3288388730                Yes  Yes
# 1180     3288378779                Yes  Yes
# 1181     3288375286                 No  NaN
# 1182     3288373068                Yes  Yes
# 1183     3288372923                Yes   No
#
#                                      Episode_1  \
# 0     Star Wars: Episode I  The Phantom Menace
# 1     Star Wars: Episode I  The Phantom Menace
# 2     Star Wars: Episode I  The Phantom Menace
# 3     Star Wars: Episode I  The Phantom Menace
# 4     Star Wars: Episode I  The Phantom Menace
# ...                                        ...
# 1179  Star Wars: Episode I  The Phantom Menace
# 1180  Star Wars: Episode I  The Phantom Menace
# 1181                                       NaN
# 1182  Star Wars: Episode I  The Phantom Menace
# 1183  Star Wars: Episode I  The Phantom Menace
#
#                                         Episode_2  \
# 0     Star Wars: Episode II  Attack of the Clones
# 1     Star Wars: Episode II  Attack of the Clones
# 2     Star Wars: Episode II  Attack of the Clones
# 3     Star Wars: Episode II  Attack of the Clones
# 4     Star Wars: Episode II  Attack of the Clones
# ...                                           ...
# 1179  Star Wars: Episode II  Attack of the Clones
# 1180  Star Wars: Episode II  Attack of the Clones
# 1181                                          NaN
# 1182  Star Wars: Episode II  Attack of the Clones
# 1183  Star Wars: Episode II  Attack of the Clones
#
#                                         Episode_3  \
# 0     Star Wars: Episode III  Revenge of the Sith
# 1     Star Wars: Episode III  Revenge of the Sith
# 2     Star Wars: Episode III  Revenge of the Sith
# 3     Star Wars: Episode III  Revenge of the Sith
# 4     Star Wars: Episode III  Revenge of the Sith
# ...                                           ...
# 1179  Star Wars: Episode III  Revenge of the Sith
# 1180  Star Wars: Episode III  Revenge of the Sith
# 1181                                          NaN
# 1182  Star Wars: Episode III  Revenge of the Sith
# 1183                                          NaN
#
#                               Episode_4  \
# 0                                   NaN
# 1     Star Wars: Episode IV  A New Hope
# 2     Star Wars: Episode IV  A New Hope
# 3     Star Wars: Episode IV  A New Hope
# 4     Star Wars: Episode IV  A New Hope
# ...                                 ...
# 1179  Star Wars: Episode IV  A New Hope
# 1180  Star Wars: Episode IV  A New Hope
# 1181                                NaN
# 1182  Star Wars: Episode IV  A New Hope
# 1183                                NaN
#
#                                          Episode_5  \
# 0                                              NaN
# 1     Star Wars: Episode V The Empire Strikes Back
# 2     Star Wars: Episode V The Empire Strikes Back
# 3     Star Wars: Episode V The Empire Strikes Back
# 4     Star Wars: Episode V The Empire Strikes Back
# ...                                            ...
# 1179  Star Wars: Episode V The Empire Strikes Back
# 1180  Star Wars: Episode V The Empire Strikes Back
# 1181                                           NaN
# 1182  Star Wars: Episode V The Empire Strikes Back
# 1183  Star Wars: Episode V The Empire Strikes Back
#
#                                      Episode_6  rank_1  ...  \
# 0                                          NaN     1.0  ...
# 1     Star Wars: Episode VI Return of the Jedi     5.0  ...
# 2     Star Wars: Episode VI Return of the Jedi     5.0  ...
# 3     Star Wars: Episode VI Return of the Jedi     1.0  ...
# 4     Star Wars: Episode VI Return of the Jedi     6.0  ...
# ...                                        ...     ...  ...
# 1179  Star Wars: Episode VI Return of the Jedi     5.0  ...
# 1180  Star Wars: Episode VI Return of the Jedi     4.0  ...
# 1181                                       NaN     NaN  ...
# 1182  Star Wars: Episode VI Return of the Jedi     4.0  ...
# 1183  Star Wars: Episode VI Return of the Jedi     6.0  ...
#
#            Yoda favored?                      shoted_first  \
# 0       Unfamiliar (N/A)  I don't understand this question
# 1         Very favorably  I don't understand this question
# 2     Somewhat favorably                            Greedo
# 3         Very favorably                               Han
# 4         Very favorably                               Han
# ...                  ...                               ...
# 1179      Very favorably                               Han
# 1180      Very favorably  I don't understand this question
# 1181                 NaN                               NaN
# 1182      Very favorably                               Han
# 1183    Very unfavorably  I don't understand this question
#
#       familiar_with_the_Expanded_Universe?  fan of the_Expanded_Universe?  \
# 0                                       No                            NaN
# 1                                       No                            NaN
# 2                                      Yes                             No
# 3                                      Yes                             No
# 4                                      Yes                             No
# ...                                    ...                            ...
# 1179                                    No                            NaN
# 1180                                    No                            NaN
# 1181                                   NaN                            NaN
# 1182                                    No                            NaN
# 1183                                    No                            NaN
#
#       fan of star_treck?  Gender    Age               Income  \
# 0                     No    Male  18-29         $0 - $24,999
# 1                    Yes    Male  18-29  $100,000 - $149,999
# 2                     No    Male  18-29  $100,000 - $149,999
# 3                    Yes    Male  18-29    $25,000 - $49,999
# 4                     No    Male  18-29                  NaN
# ...                  ...     ...    ...                  ...
# 1179                 Yes  Female  18-29         $0 - $24,999
# 1180                 Yes  Female  30-44    $50,000 - $99,999
# 1181                  No  Female  30-44    $50,000 - $99,999
# 1182                 Yes  Female  45-60  $100,000 - $149,999
# 1183                  No  Female   > 60    $50,000 - $99,999
#
#                              Education            Location
# 0                   High school degree  West North Central
# 1     Some college or Associate degree  West North Central
# 2     Some college or Associate degree  West North Central
# 3                      Bachelor degree     Middle Atlantic
# 4                   High school degree  East North Central
# ...                                ...                 ...
# 1179  Some college or Associate degree  East North Central
# 1180                   Bachelor degree            Mountain
# 1181                   Bachelor degree     Middle Atlantic
# 1182  Some college or Associate degree  East North Central
# 1183                   Graduate degree             Pacific
#
# [1184 rows x 38 columns]

# %%
#display all columns in starwars file

StarWars.columns
# Out:
# Index(['Respondant ID', 'seen_any_of_6films', 'fan?', 'Episode_1', 'Episode_2',
#        'Episode_3', 'Episode_4', 'Episode_5', 'Episode_6', 'rank_1', 'rank_2',
#        'rank_3', 'rank_4', 'rank_5', 'rank_6', 'Han Solo favored?',
#        'Luke Skywalker favored?', 'Princess Leia Organa favored?',
#        'Anakin Skywalker favored?', 'Obi Wan Kenobi favored?',
#        'Emperor Palpatine favored?', 'Darth Vader favored?',
#        'Lando Calrissian favored?', 'Boba Fett favored?', 'C-3P0 favored?',
#        'R2 D2 favored?', 'Jar Jar Binks favored?', 'Padme Amidala favored?',
#        'Yoda favored?', 'shoted_first', 'familiar_with_the_Expanded_Universe?',
#        'fan of the_Expanded_Universe?', 'fan of star_treck?', 'Gender', 'Age',
#        'Income', 'Education', 'Location'],
#       dtype='object')

# %%
#ques 1.2
#Check datatypes of all columns

StarWars.dtypes
# Out:
# Respondant ID                             int64
# seen_any_of_6films                       object
# fan?                                     object
# Episode_1                                object
# Episode_2                                object
# Episode_3                                object
# Episode_4                                object
# Episode_5                                object
# Episode_6                                object
# rank_1                                  float64
# rank_2                                  float64
# rank_3                                  float64
# rank_4                                  float64
# rank_5                                  float64
# rank_6                                  float64
# Han Solo favored?                        object
# Luke Skywalker favored?                  object
# Princess Leia Organa favored?            object
# Anakin Skywalker favored?                object
# Obi Wan Kenobi favored?                  object
# Emperor Palpatine favored?               object
# Darth Vader favored?                     object
# Lando Calrissian favored?                object
# Boba Fett favored?                       object
# C-3P0 favored?                           object
# R2 D2 favored?                           object
# Jar Jar Binks favored?                   object
# Padme Amidala favored?                   object
# Yoda favored?                            object
# shoted_first                             object
# familiar_with_the_Expanded_Universe?     object
# fan of the_Expanded_Universe?            object
# fan of star_treck?                       object
# Gender                                   object
# Age                                      object
# Income                                   object
# Education                                object
# Location                                 object
# dtype: object

# %%
StarWars.shape
# Out:
# (1184, 38)

# %%
#creating a dataframe of starwars

df=pd.DataFrame(StarWars)

# %%
#using a 'for loop' to count all the values the columns contains

for c in df.columns:
    print ("---- %s ---" % c)
    print (df[c].value_counts())
# Out:
# ---- Respondant ID ---
# 3289370623    1
# 3290063543    1
# 3289539921    1
# 3290206907    1
# 3291022013    1
#              ..
# 3289481310    1
# 3290944858    1
# 3288653149    1
# 3290428766    1
# 3289878528    1
# Name: Respondant ID, Length: 1184, dtype: int64
# ---- seen_any_of_6films ---
# Yes     934
# No      249
# Yes       1
# Name: seen_any_of_6films, dtype: int64
# ---- fan? ---
# Yes     550
# No      283
# Yess      1
# Noo       1
# Name: fan?, dtype: int64
# ---- Episode_1 ---
# Star Wars: Episode I  The Phantom Menace    672
# Name: Episode_1, dtype: int64
# ---- Episode_2 ---
# Star Wars: Episode II  Attack of the Clones    570
# Name: Episode_2, dtype: int64
# ---- Episode_3 ---
# Star Wars: Episode III  Revenge of the Sith    549
# Name: Episode_3, dtype: int64
# ---- Episode_4 ---
# Star Wars: Episode IV  A New Hope    606
# Name: Episode_4, dtype: int64
# ---- Episode_5 ---
# Star Wars: Episode V The Empire Strikes Back    757
# Name: Episode_5, dtype: int64
# ---- Episode_6 ---
# Star Wars: Episode VI Return of the Jedi    737
# Name: Episode_6, dtype: int64
# ---- rank_1 ---
# 4.0    237
# 6.0    168
# 3.0    129
# 1.0    129
# 5.0    100
# 2.0     71
# Name: rank_1, dtype: int64
# ---- rank_2 ---
# 5.0    300
# 4.0    183
# 2.0    115
# 3.0    103
# 6.0    102
# 1.0     32
# Name: rank_2, dtype: int64
# ---- rank_3 ---
# 6.0    217
# 5.0    203
# 4.0    182
# 3.0    150
# 2.0     47
# 1.0     35
# Name: rank_3, dtype: int64
# ---- rank_4 ---
# 1.0    204
# 6.0    161
# 2.0    135
# 4.0    129
# 3.0    127
# 5.0     79
# Name: rank_4, dtype: int64
# ---- rank_5 ---
# 1.0    289
# 2.0    235
# 5.0    117
# 3.0    106
# 4.0     47
# 6.0     41
# Name: rank_5, dtype: int64
# ---- rank_6 ---
# 2.0    232
# 3.0    220
# 1.0    146
# 6.0    144
# 4.0     57
# 5.0     36
# Name: rank_6, dtype: int64
# ---- Han Solo favored? ---
# Very favorably                                 609
# Somewhat favorably                             151
# Neither favorably nor unfavorably (neutral)     44
# Unfamiliar (N/A)                                15
# Somewhat unfavorably                             8
# Very unfavorably                                 1
# Name: Han Solo favored?, dtype: int64
# ---- Luke Skywalker favored? ---
# Very favorably                                 551
# Somewhat favorably                             219
# Neither favorably nor unfavorably (neutral)     38
# Somewhat unfavorably                            13
# Unfamiliar (N/A)                                 6
# Very unfavorably                                 3
# Name: Luke Skywalker favored?, dtype: int64
# ---- Princess Leia Organa favored? ---
# Very favorably                                 546
# Somewhat favorably                             210
# Neither favorably nor unfavorably (neutral)     48
# Somewhat unfavorably                            12
# Unfamiliar (N/A)                                 8
# Very unfavorably                                 6
# Name: Princess Leia Organa favored?, dtype: int64
# ---- Anakin Skywalker favored? ---
# Somewhat favorably                             269
# Very favorably                                 244
# Neither favorably nor unfavorably (neutral)    135
# Somewhat unfavorably                            83
# Unfamiliar (N/A)                                52
# Very unfavorably                                39
# Name: Anakin Skywalker favored?, dtype: int64
# ---- Obi Wan Kenobi favored? ---
# Very favorably                                 590
# Somewhat favorably                             159
# Neither favorably nor unfavorably (neutral)     43
# Unfamiliar (N/A)                                17
# Somewhat unfavorably                             8
# Very unfavorably                                 7
# Name: Obi Wan Kenobi favored?, dtype: int64
# ---- Emperor Palpatine favored? ---
# Neither favorably nor unfavorably (neutral)    213
# Unfamiliar (N/A)                               156
# Somewhat favorably                             143
# Very unfavorably                               124
# Very favorably                                 109
# Somewhat unfavorably                            68
# Name: Emperor Palpatine favored?, dtype: int64
# ---- Darth Vader favored? ---
# Very favorably                                 309
# Somewhat favorably                             171
# Very unfavorably                               149
# Somewhat unfavorably                           102
# Neither favorably nor unfavorably (neutral)     84
# Unfamiliar (N/A)                                10
# Name: Darth Vader favored?, dtype: int64
# ---- Lando Calrissian favored? ---
# Neither favorably nor unfavorably (neutral)    236
# Somewhat favorably                             223
# Unfamiliar (N/A)                               147
# Very favorably                                 142
# Somewhat unfavorably                            63
# Very unfavorably                                 8
# Name: Lando Calrissian favored?, dtype: int64
# ---- Boba Fett favored? ---
# Neither favorably nor unfavorably (neutral)    248
# Somewhat favorably                             153
# Very favorably                                 138
# Unfamiliar (N/A)                               131
# Somewhat unfavorably                            96
# Very unfavorably                                45
# Name: Boba Fett favored?, dtype: int64
# ---- C-3P0 favored? ---
# Very favorably                                 473
# Somewhat favorably                             229
# Neither favorably nor unfavorably (neutral)     79
# Somewhat unfavorably                            23
# Unfamiliar (N/A)                                15
# Very unfavorably                                 7
# Name: C-3P0 favored?, dtype: int64
# ---- R2 D2 favored? ---
# Very favorably                                 561
# Somewhat favorably                             185
# Neither favorably nor unfavorably (neutral)     57
# Unfamiliar (N/A)                                10
# Somewhat unfavorably                            10
# Very unfavorably                                 6
# Name: R2 D2 favored?, dtype: int64
# ---- Jar Jar Binks favored? ---
# Very unfavorably                               204
# Neither favorably nor unfavorably (neutral)    164
# Somewhat favorably                             130
# Very favorably                                 111
# Unfamiliar (N/A)                               109
# Somewhat unfavorably                           102
# Name: Jar Jar Binks favored?, dtype: int64
# ---- Padme Amidala favored? ---
# Neither favorably nor unfavorably (neutral)    207
# Somewhat favorably                             183
# Very favorably                                 167
# Unfamiliar (N/A)                               164
# Somewhat unfavorably                            58
# Very unfavorably                                34
# Name: Padme Amidala favored?, dtype: int64
# ---- Yoda favored? ---
# Very favorably                                 604
# Somewhat favorably                             144
# Neither favorably nor unfavorably (neutral)     51
# Unfamiliar (N/A)                                10
# Very unfavorably                                 8
# Somewhat unfavorably                             8
# Name: Yoda favored?, dtype: int64
# ---- shoted_first ---
# Han                                 325
# I don't understand this question    305
# Greedo                              197
# Name: shoted_first, dtype: int64
# ---- familiar_with_the_Expanded_Universe? ---
# No     615
# Yes    212
# Name: familiar_with_the_Expanded_Universe?, dtype: int64
# ---- fan of the_Expanded_Universe? ---
# No      113
# Yes      98
# Yess      1
# Name: fan of the_Expanded_Universe?, dtype: int64
# ---- fan of star_treck? ---
# No     638
# Yes    425
# yes      1
# Noo      1
# no       1
# Name: fan of star_treck?, dtype: int64
# ---- Gender ---
# Female    546
# Male      494
# female      2
# male        1
# F           1
# Name: Gender, dtype: int64
# ---- Age ---
# 45-60    291
# > 60     269
# 30-44    268
# 18-29    215
# 500        1
# Name: Age, dtype: int64
# ---- Income ---
# $50,000 - $99,999      298
# $25,000 - $49,999      186
# $100,000 - $149,999    141
# $0 - $24,999           137
# $150,000+               95
# Name: Income, dtype: int64
# ---- Education ---
# Some college or Associate degree    328
# Bachelor degree                     320
# Graduate degree                     275
# High school degree                  104
# Less than high school degree          7
# Name: Education, dtype: int64
# ---- Location ---
# East North Central    181
# Pacific               175
# South Atlantic        169
# Middle Atlantic       122
# West South Central    109
# West North Central     93
# Mountain               79
# New England            75
# East South Central     38
# Name: Location, dtype: int64

# %%
#ques 1.3
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['seen_any_of_6films'].unique()
# Out:
# array(['Yes', 'No', 'Yes '], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['fan?'].unique()
# Out:
# array(['No', 'Yes', nan, 'Yess', 'Noo'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Episode_1'].unique()
# Out:
# array(['Star Wars: Episode I  The Phantom Menace', nan], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Episode_2'].unique()
# Out:
# array(['Star Wars: Episode II  Attack of the Clones', nan], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Episode_3'].unique()
# Out:
# array(['Star Wars: Episode III  Revenge of the Sith', nan], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Episode_4'].unique()
# Out:
# array([nan, 'Star Wars: Episode IV  A New Hope'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Episode_5'].unique()
# Out:
# array([nan, 'Star Wars: Episode V The Empire Strikes Back'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Episode_6'].unique()
# Out:
# array([nan, 'Star Wars: Episode VI Return of the Jedi'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['rank_1'].unique()
# Out:
# array([ 1.,  5.,  6.,  4., nan,  3.,  2.])

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['rank_2'].unique()
# Out:
# array([ 2.,  6.,  4.,  5., nan,  1.,  3.])

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['rank_3'].unique()
# Out:
# array([ 3.,  1.,  6.,  4., nan,  5.,  2.])

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['rank_4'].unique()
# Out:
# array([ 4.,  2.,  6.,  3., nan,  1.,  5.])

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['rank_5'].unique()
# Out:
# array([ 5.,  4.,  1.,  2., nan,  3.,  6.])

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['rank_6'].unique()
# Out:
# array([ 6.,  3.,  2.,  1., nan,  4.,  5.])

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Han Solo favored?'].unique()
# Out:
# array(['Somewhat favorably', 'Very favorably',
#        'Neither favorably nor unfavorably (neutral)', nan,
#        'Somewhat unfavorably', 'Unfamiliar (N/A)', 'Very unfavorably'],
#       dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Luke Skywalker favored?'].unique()
# Out:
# array(['Somewhat favorably', 'Very favorably', 'Somewhat unfavorably',
#        nan, 'Neither favorably nor unfavorably (neutral)',
#        'Very unfavorably', 'Unfamiliar (N/A)'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Princess Leia Organa favored?'].unique()
# Out:
# array(['Somewhat favorably', 'Very favorably', nan,
#        'Somewhat unfavorably',
#        'Neither favorably nor unfavorably (neutral)', 'Very unfavorably',
#        'Unfamiliar (N/A)'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Anakin Skywalker favored?'].unique()
# Out:
# array(['Somewhat favorably', 'Very favorably', 'Somewhat unfavorably',
#        'Neither favorably nor unfavorably (neutral)', nan,
#        'Very unfavorably', 'Unfamiliar (N/A)'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Obi Wan Kenobi favored?'].unique()
# Out:
# array(['Somewhat favorably', 'Very favorably', nan, 'Very unfavorably',
#        'Neither favorably nor unfavorably (neutral)',
#        'Somewhat unfavorably', 'Unfamiliar (N/A)'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Emperor Palpatine favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Somewhat favorably', 'Very unfavorably',
#        'Neither favorably nor unfavorably (neutral)', 'Very favorably',
#        'Somewhat unfavorably', nan], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Darth Vader favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Very favorably', 'Somewhat favorably',
#        'Somewhat unfavorably', nan, 'Very unfavorably',
#        'Neither favorably nor unfavorably (neutral)'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Lando Calrissian favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Somewhat favorably',
#        'Neither favorably nor unfavorably (neutral)', 'Very favorably',
#        'Somewhat unfavorably', nan, 'Very unfavorably'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Boba Fett favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Somewhat unfavorably', 'Very favorably',
#        'Somewhat favorably', nan,
#        'Neither favorably nor unfavorably (neutral)', 'Very unfavorably'],
#       dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['C-3P0 favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Very favorably', 'Somewhat favorably',
#        'Neither favorably nor unfavorably (neutral)', nan,
#        'Somewhat unfavorably', 'Very unfavorably'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['R2 D2 favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Very favorably', 'Somewhat favorably', nan,
#        'Neither favorably nor unfavorably (neutral)',
#        'Somewhat unfavorably', 'Very unfavorably'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Jar Jar Binks favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Very favorably', 'Very unfavorably',
#        'Somewhat favorably', 'Somewhat unfavorably', nan,
#        'Neither favorably nor unfavorably (neutral)'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Padme Amidala favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Very favorably', 'Somewhat favorably',
#        'Neither favorably nor unfavorably (neutral)',
#        'Somewhat unfavorably', nan, 'Very unfavorably'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Yoda favored?'].unique()
# Out:
# array(['Unfamiliar (N/A)', 'Very favorably', 'Somewhat favorably', nan,
#        'Very unfavorably', 'Neither favorably nor unfavorably (neutral)',
#        'Somewhat unfavorably'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['shoted_first'].unique()
# Out:
# array(["I don't understand this question", 'Greedo', 'Han', nan],
#       dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['familiar_with_the_Expanded_Universe?'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['fan of the_Expanded_Universe?'].unique()
# Out:
# array([nan, 'No', 'Yes', 'Yess'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['fan of star_treck?'].unique()
# Out:
# array(['No', 'Yes', nan, 'Noo', 'yes', 'no '], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'F', 'female', 'male'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Age'].unique()
# Out:
# array(['18-29', nan, '500', '30-44', '> 60', '45-60'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Income'].unique()
# Out:
# array(['$0 - $24,999', '$100,000 - $149,999', '$25,000 - $49,999', nan,
#        '$50,000 - $99,999', '$150,000+'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Education'].unique()
# Out:
# array(['High school degree', 'Some college or Associate degree',
#        'Bachelor degree', nan, 'Graduate degree',
#        'Less than high school degree'], dtype=object)

# %%
#extracting the unique values in the column for detecting any typos/impossible values
StarWars['Location'].unique()
# Out:
# array(['West North Central', 'Middle Atlantic', 'East North Central',
#        'South Atlantic', 'Pacific', nan, 'Mountain', 'West South Central',
#        'New England', 'East South Central'], dtype=object)

# %%
#checking and counting typos in 'fan?' column using mask

mask1=StarWars['fan?']=='Noo'
mask1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: fan?, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'fan?' column using mask

mask1=StarWars['fan?']=='Yess'
mask1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: fan?, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'fan of the_Expanded_Universe?' column using mask

mask2=StarWars['fan of the_Expanded_Universe?']=='Yess'
mask2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: fan of the_Expanded_Universe?, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'fan of star_treck? column using mask

mask3=StarWars['fan of star_treck?']=='Noo'
mask3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: fan of star_treck?, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'fan of star_treck? column using mask

mask4=StarWars['fan of star_treck?']=='yes'
mask4
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: fan of star_treck?, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'Gender' column using mask

mask5=StarWars['Gender']=='female'
mask5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: Gender, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'Gender' column using mask

mask6=StarWars['Gender']=='male'
mask6
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: Gender, Length: 1184, dtype: bool

# %%
#checking and counting typos in 'Gender' column using mask

mask7=StarWars['Gender']=='F'
mask7
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: Gender, Length: 1184, dtype: bool

# %%
#replacing all the typos found above by the standard value

StarWars['fan?'].replace('Noo','No',inplace=True)
StarWars['fan?'].replace('Yess','Yes',inplace=True)
StarWars['fan?'].value_counts()

StarWars['fan of the_Expanded_Universe?'].replace('Yess','Yes',inplace=True)
StarWars['fan of the_Expanded_Universe?'].value_counts()

StarWars['fan of star_treck?'].replace('Noo','No',inplace=True)
StarWars['fan of star_treck?'].replace('yes','Yes',inplace=True)
StarWars['fan of star_treck?'].value_counts()

StarWars['Gender'].replace('female','Female',inplace=True)
StarWars['Gender'].replace('male','Male',inplace=True)
StarWars['Gender'].replace('F','Female',inplace=True)
StarWars['Gender'].value_counts()
# Out:
# Female    549
# Male      495
# Name: Gender, dtype: int64

# %%
#checking for extra white space and removing them and then replacing them with standard value as it has typos too

StarWars['fan of star_treck?']=StarWars['fan of star_treck?'].str.strip()
StarWars['fan of star_treck?'].replace('no','No',inplace=True)
StarWars['fan of star_treck?'].value_counts()
# Out:
# No     640
# Yes    426
# Name: fan of star_treck?, dtype: int64

# %%
#checking for extra white space and display the updated counts

StarWars['seen_any_of_6films']=StarWars['seen_any_of_6films'].str.strip()
StarWars['seen_any_of_6films'].value_counts()
# Out:
# Yes    935
# No     249
# Name: seen_any_of_6films, dtype: int64

# %%
#display updated all column values

for c in df.columns:
    print ("---- %s ---" % c)
    print (df[c].value_counts())
# Out:
# ---- Respondant ID ---
# 3289370623    1
# 3290063543    1
# 3289539921    1
# 3290206907    1
# 3291022013    1
#              ..
# 3289481310    1
# 3290944858    1
# 3288653149    1
# 3290428766    1
# 3289878528    1
# Name: Respondant ID, Length: 1184, dtype: int64
# ---- seen_any_of_6films ---
# Yes    935
# No     249
# Name: seen_any_of_6films, dtype: int64
# ---- fan? ---
# Yes    551
# No     284
# Name: fan?, dtype: int64
# ---- Episode_1 ---
# Star Wars: Episode I  The Phantom Menace    672
# Name: Episode_1, dtype: int64
# ---- Episode_2 ---
# Star Wars: Episode II  Attack of the Clones    570
# Name: Episode_2, dtype: int64
# ---- Episode_3 ---
# Star Wars: Episode III  Revenge of the Sith    549
# Name: Episode_3, dtype: int64
# ---- Episode_4 ---
# Star Wars: Episode IV  A New Hope    606
# Name: Episode_4, dtype: int64
# ---- Episode_5 ---
# Star Wars: Episode V The Empire Strikes Back    757
# Name: Episode_5, dtype: int64
# ---- Episode_6 ---
# Star Wars: Episode VI Return of the Jedi    737
# Name: Episode_6, dtype: int64
# ---- rank_1 ---
# 4.0    237
# 6.0    168
# 3.0    129
# 1.0    129
# 5.0    100
# 2.0     71
# Name: rank_1, dtype: int64
# ---- rank_2 ---
# 5.0    300
# 4.0    183
# 2.0    115
# 3.0    103
# 6.0    102
# 1.0     32
# Name: rank_2, dtype: int64
# ---- rank_3 ---
# 6.0    217
# 5.0    203
# 4.0    182
# 3.0    150
# 2.0     47
# 1.0     35
# Name: rank_3, dtype: int64
# ---- rank_4 ---
# 1.0    204
# 6.0    161
# 2.0    135
# 4.0    129
# 3.0    127
# 5.0     79
# Name: rank_4, dtype: int64
# ---- rank_5 ---
# 1.0    289
# 2.0    235
# 5.0    117
# 3.0    106
# 4.0     47
# 6.0     41
# Name: rank_5, dtype: int64
# ---- rank_6 ---
# 2.0    232
# 3.0    220
# 1.0    146
# 6.0    144
# 4.0     57
# 5.0     36
# Name: rank_6, dtype: int64
# ---- Han Solo favored? ---
# Very favorably                                 609
# Somewhat favorably                             151
# Neither favorably nor unfavorably (neutral)     44
# Unfamiliar (N/A)                                15
# Somewhat unfavorably                             8
# Very unfavorably                                 1
# Name: Han Solo favored?, dtype: int64
# ---- Luke Skywalker favored? ---
# Very favorably                                 551
# Somewhat favorably                             219
# Neither favorably nor unfavorably (neutral)     38
# Somewhat unfavorably                            13
# Unfamiliar (N/A)                                 6
# Very unfavorably                                 3
# Name: Luke Skywalker favored?, dtype: int64
# ---- Princess Leia Organa favored? ---
# Very favorably                                 546
# Somewhat favorably                             210
# Neither favorably nor unfavorably (neutral)     48
# Somewhat unfavorably                            12
# Unfamiliar (N/A)                                 8
# Very unfavorably                                 6
# Name: Princess Leia Organa favored?, dtype: int64
# ---- Anakin Skywalker favored? ---
# Somewhat favorably                             269
# Very favorably                                 244
# Neither favorably nor unfavorably (neutral)    135
# Somewhat unfavorably                            83
# Unfamiliar (N/A)                                52
# Very unfavorably                                39
# Name: Anakin Skywalker favored?, dtype: int64
# ---- Obi Wan Kenobi favored? ---
# Very favorably                                 590
# Somewhat favorably                             159
# Neither favorably nor unfavorably (neutral)     43
# Unfamiliar (N/A)                                17
# Somewhat unfavorably                             8
# Very unfavorably                                 7
# Name: Obi Wan Kenobi favored?, dtype: int64
# ---- Emperor Palpatine favored? ---
# Neither favorably nor unfavorably (neutral)    213
# Unfamiliar (N/A)                               156
# Somewhat favorably                             143
# Very unfavorably                               124
# Very favorably                                 109
# Somewhat unfavorably                            68
# Name: Emperor Palpatine favored?, dtype: int64
# ---- Darth Vader favored? ---
# Very favorably                                 309
# Somewhat favorably                             171
# Very unfavorably                               149
# Somewhat unfavorably                           102
# Neither favorably nor unfavorably (neutral)     84
# Unfamiliar (N/A)                                10
# Name: Darth Vader favored?, dtype: int64
# ---- Lando Calrissian favored? ---
# Neither favorably nor unfavorably (neutral)    236
# Somewhat favorably                             223
# Unfamiliar (N/A)                               147
# Very favorably                                 142
# Somewhat unfavorably                            63
# Very unfavorably                                 8
# Name: Lando Calrissian favored?, dtype: int64
# ---- Boba Fett favored? ---
# Neither favorably nor unfavorably (neutral)    248
# Somewhat favorably                             153
# Very favorably                                 138
# Unfamiliar (N/A)                               131
# Somewhat unfavorably                            96
# Very unfavorably                                45
# Name: Boba Fett favored?, dtype: int64
# ---- C-3P0 favored? ---
# Very favorably                                 473
# Somewhat favorably                             229
# Neither favorably nor unfavorably (neutral)     79
# Somewhat unfavorably                            23
# Unfamiliar (N/A)                                15
# Very unfavorably                                 7
# Name: C-3P0 favored?, dtype: int64
# ---- R2 D2 favored? ---
# Very favorably                                 561
# Somewhat favorably                             185
# Neither favorably nor unfavorably (neutral)     57
# Unfamiliar (N/A)                                10
# Somewhat unfavorably                            10
# Very unfavorably                                 6
# Name: R2 D2 favored?, dtype: int64
# ---- Jar Jar Binks favored? ---
# Very unfavorably                               204
# Neither favorably nor unfavorably (neutral)    164
# Somewhat favorably                             130
# Very favorably                                 111
# Unfamiliar (N/A)                               109
# Somewhat unfavorably                           102
# Name: Jar Jar Binks favored?, dtype: int64
# ---- Padme Amidala favored? ---
# Neither favorably nor unfavorably (neutral)    207
# Somewhat favorably                             183
# Very favorably                                 167
# Unfamiliar (N/A)                               164
# Somewhat unfavorably                            58
# Very unfavorably                                34
# Name: Padme Amidala favored?, dtype: int64
# ---- Yoda favored? ---
# Very favorably                                 604
# Somewhat favorably                             144
# Neither favorably nor unfavorably (neutral)     51
# Unfamiliar (N/A)                                10
# Very unfavorably                                 8
# Somewhat unfavorably                             8
# Name: Yoda favored?, dtype: int64
# ---- shoted_first ---
# Han                                 325
# I don't understand this question    305
# Greedo                              197
# Name: shoted_first, dtype: int64
# ---- familiar_with_the_Expanded_Universe? ---
# No     615
# Yes    212
# Name: familiar_with_the_Expanded_Universe?, dtype: int64
# ---- fan of the_Expanded_Universe? ---
# No     113
# Yes     99
# Name: fan of the_Expanded_Universe?, dtype: int64
# ---- fan of star_treck? ---
# No     640
# Yes    426
# Name: fan of star_treck?, dtype: int64
# ---- Gender ---
# Female    549
# Male      495
# Name: Gender, dtype: int64
# ---- Age ---
# 45-60    291
# > 60     269
# 30-44    268
# 18-29    215
# 500        1
# Name: Age, dtype: int64
# ---- Income ---
# $50,000 - $99,999      298
# $25,000 - $49,999      186
# $100,000 - $149,999    141
# $0 - $24,999           137
# $150,000+               95
# Name: Income, dtype: int64
# ---- Education ---
# Some college or Associate degree    328
# Bachelor degree                     320
# Graduate degree                     275
# High school degree                  104
# Less than high school degree          7
# Name: Education, dtype: int64
# ---- Location ---
# East North Central    181
# Pacific               175
# South Atlantic        169
# Middle Atlantic       122
# West South Central    109
# West North Central     93
# Mountain               79
# New England            75
# East South Central     38
# Name: Location, dtype: int64

# %%
#converting all text data to upper case by using 'str.upper()' function and updating it to that particular column itself
    
StarWars['seen_any_of_6films']=StarWars['seen_any_of_6films'].str.upper()
StarWars['fan?']=StarWars['fan?'].str.upper()
StarWars['Episode_1']=StarWars['Episode_1'].str.upper()
StarWars['Episode_2']=StarWars['Episode_2'].str.upper()
StarWars['Episode_3']=StarWars['Episode_3'].str.upper()
StarWars['Episode_4']=StarWars['Episode_4'].str.upper()
StarWars['Episode_5']=StarWars['Episode_5'].str.upper()
StarWars['Episode_6']=StarWars['Episode_6'].str.upper()
StarWars['Han Solo favored?']=StarWars['Han Solo favored?'].str.upper()
StarWars['Luke Skywalker favored?']=StarWars['Luke Skywalker favored?'].str.upper()
StarWars['Princess Leia Organa favored?']=StarWars['Princess Leia Organa favored?'].str.upper()
StarWars['Anakin Skywalker favored?']=StarWars['Anakin Skywalker favored?'].str.upper()
StarWars['Obi Wan Kenobi favored?']=StarWars['Obi Wan Kenobi favored?'].str.upper()
StarWars['Emperor Palpatine favored?']=StarWars['Emperor Palpatine favored?'].str.upper()
StarWars['Darth Vader favored?']=StarWars['Darth Vader favored?'].str.upper()
StarWars['Lando Calrissian favored?']=StarWars['Lando Calrissian favored?'].str.upper()
StarWars['Boba Fett favored?']=StarWars['Boba Fett favored?'].str.upper()
StarWars['C-3P0 favored?']=StarWars['C-3P0 favored?'].str.upper()
StarWars['R2 D2 favored?']=StarWars['R2 D2 favored?'].str.upper()
StarWars['Jar Jar Binks favored?']=StarWars['Jar Jar Binks favored?'].str.upper()
StarWars['Padme Amidala favored?']=StarWars['Padme Amidala favored?'].str.upper()
StarWars['Yoda favored?']=StarWars['Yoda favored?'].str.upper()
StarWars['shoted_first']=StarWars['shoted_first'].str.upper()
StarWars['fan of the_Expanded_Universe?']=StarWars['fan of the_Expanded_Universe?'].str.upper()
StarWars['fan of star_treck?']=StarWars['fan of star_treck?'].str.upper()
StarWars['Gender']=StarWars['Gender'].str.upper()
StarWars['Age']=StarWars['Age'].str.upper()
StarWars['Income']=StarWars['Income'].str.upper()
StarWars['Education']=StarWars['Education'].str.upper()
StarWars['Location']=StarWars['Location'].str.upper()

# %%
#displaying updated StarWars file

StarWars
# Out:
#       Respondant ID seen_any_of_6films fan?  \
# 0        3292765271                YES   NO
# 1        3292763116                YES  YES
# 2        3292731220                YES  YES
# 3        3292719380                YES  YES
# 4        3292684787                YES  YES
# ...             ...                ...  ...
# 1179     3288388730                YES  YES
# 1180     3288378779                YES  YES
# 1181     3288375286                 NO  NaN
# 1182     3288373068                YES  YES
# 1183     3288372923                YES   NO
#
#                                      Episode_1  \
# 0     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 2     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 3     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 4     STAR WARS: EPISODE I  THE PHANTOM MENACE
# ...                                        ...
# 1179  STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1180  STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1181                                       NaN
# 1182  STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1183  STAR WARS: EPISODE I  THE PHANTOM MENACE
#
#                                         Episode_2  \
# 0     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 2     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 3     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 4     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# ...                                           ...
# 1179  STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1180  STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1181                                          NaN
# 1182  STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1183  STAR WARS: EPISODE II  ATTACK OF THE CLONES
#
#                                         Episode_3  \
# 0     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 2     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 3     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 4     STAR WARS: EPISODE III  REVENGE OF THE SITH
# ...                                           ...
# 1179  STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1180  STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1181                                          NaN
# 1182  STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1183                                          NaN
#
#                               Episode_4  \
# 0                                   NaN
# 1     STAR WARS: EPISODE IV  A NEW HOPE
# 2     STAR WARS: EPISODE IV  A NEW HOPE
# 3     STAR WARS: EPISODE IV  A NEW HOPE
# 4     STAR WARS: EPISODE IV  A NEW HOPE
# ...                                 ...
# 1179  STAR WARS: EPISODE IV  A NEW HOPE
# 1180  STAR WARS: EPISODE IV  A NEW HOPE
# 1181                                NaN
# 1182  STAR WARS: EPISODE IV  A NEW HOPE
# 1183                                NaN
#
#                                          Episode_5  \
# 0                                              NaN
# 1     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 2     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 3     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 4     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# ...                                            ...
# 1179  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 1180  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 1181                                           NaN
# 1182  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 1183  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
#
#                                      Episode_6  rank_1  ...  \
# 0                                          NaN     1.0  ...
# 1     STAR WARS: EPISODE VI RETURN OF THE JEDI     5.0  ...
# 2     STAR WARS: EPISODE VI RETURN OF THE JEDI     5.0  ...
# 3     STAR WARS: EPISODE VI RETURN OF THE JEDI     1.0  ...
# 4     STAR WARS: EPISODE VI RETURN OF THE JEDI     6.0  ...
# ...                                        ...     ...  ...
# 1179  STAR WARS: EPISODE VI RETURN OF THE JEDI     5.0  ...
# 1180  STAR WARS: EPISODE VI RETURN OF THE JEDI     4.0  ...
# 1181                                       NaN     NaN  ...
# 1182  STAR WARS: EPISODE VI RETURN OF THE JEDI     4.0  ...
# 1183  STAR WARS: EPISODE VI RETURN OF THE JEDI     6.0  ...
#
#            Yoda favored?                      shoted_first  \
# 0       UNFAMILIAR (N/A)  I DON'T UNDERSTAND THIS QUESTION
# 1         VERY FAVORABLY  I DON'T UNDERSTAND THIS QUESTION
# 2     SOMEWHAT FAVORABLY                            GREEDO
# 3         VERY FAVORABLY                               HAN
# 4         VERY FAVORABLY                               HAN
# ...                  ...                               ...
# 1179      VERY FAVORABLY                               HAN
# 1180      VERY FAVORABLY  I DON'T UNDERSTAND THIS QUESTION
# 1181                 NaN                               NaN
# 1182      VERY FAVORABLY                               HAN
# 1183    VERY UNFAVORABLY  I DON'T UNDERSTAND THIS QUESTION
#
#       familiar_with_the_Expanded_Universe?  fan of the_Expanded_Universe?  \
# 0                                       No                            NaN
# 1                                       No                            NaN
# 2                                      Yes                             NO
# 3                                      Yes                             NO
# 4                                      Yes                             NO
# ...                                    ...                            ...
# 1179                                    No                            NaN
# 1180                                    No                            NaN
# 1181                                   NaN                            NaN
# 1182                                    No                            NaN
# 1183                                    No                            NaN
#
#       fan of star_treck?  Gender    Age               Income  \
# 0                     NO    MALE  18-29         $0 - $24,999
# 1                    YES    MALE  18-29  $100,000 - $149,999
# 2                     NO    MALE  18-29  $100,000 - $149,999
# 3                    YES    MALE  18-29    $25,000 - $49,999
# 4                     NO    MALE  18-29                  NaN
# ...                  ...     ...    ...                  ...
# 1179                 YES  FEMALE  18-29         $0 - $24,999
# 1180                 YES  FEMALE  30-44    $50,000 - $99,999
# 1181                  NO  FEMALE  30-44    $50,000 - $99,999
# 1182                 YES  FEMALE  45-60  $100,000 - $149,999
# 1183                  NO  FEMALE   > 60    $50,000 - $99,999
#
#                              Education            Location
# 0                   HIGH SCHOOL DEGREE  WEST NORTH CENTRAL
# 1     SOME COLLEGE OR ASSOCIATE DEGREE  WEST NORTH CENTRAL
# 2     SOME COLLEGE OR ASSOCIATE DEGREE  WEST NORTH CENTRAL
# 3                      BACHELOR DEGREE     MIDDLE ATLANTIC
# 4                   HIGH SCHOOL DEGREE  EAST NORTH CENTRAL
# ...                                ...                 ...
# 1179  SOME COLLEGE OR ASSOCIATE DEGREE  EAST NORTH CENTRAL
# 1180                   BACHELOR DEGREE            MOUNTAIN
# 1181                   BACHELOR DEGREE     MIDDLE ATLANTIC
# 1182  SOME COLLEGE OR ASSOCIATE DEGREE  EAST NORTH CENTRAL
# 1183                   GRADUATE DEGREE             PACIFIC
#
# [1184 rows x 38 columns]

# %%
#using describe function for sanity check, for finding any impossible value
StarWars.describe()
# Out:
#        Respondant ID      rank_1      rank_2      rank_3      rank_4  \
# count   1.184000e+03  834.000000  835.000000  834.000000  835.000000
# mean    3.290124e+09    3.733813    4.089820    4.345324    3.271856
# std     1.050446e+06    1.656921    1.364268    1.396509    1.826821
# min     3.288373e+09    1.000000    1.000000    1.000000    1.000000
# 25%     3.289450e+09    3.000000    3.000000    3.000000    2.000000
# 50%     3.290144e+09    4.000000    4.000000    5.000000    3.000000
# 75%     3.290811e+09    5.000000    5.000000    6.000000    5.000000
# max     3.292765e+09    6.000000    6.000000    6.000000    6.000000
#
#            rank_5      rank_6
# count  835.000000  835.000000
# mean     2.510180    3.044311
# std      1.577215    1.664757
# min      1.000000    1.000000
# 25%      1.000000    2.000000
# 50%      2.000000    3.000000
# 75%      3.000000    4.000000
# max      6.000000    6.000000

# %%
#displaying impossible value in 'Age' column
StarWars['Age']=='500'
StarWars['Age'].iloc[5:15]
# Out:
# 5     18-29
# 6     18-29
# 7     18-29
# 8       NaN
# 9       NaN
# 10      500
# 11    30-44
# 12    18-29
# 13    18-29
# 14    18-29
# Name: Age, dtype: object

# %%
#selcting that particular impossible value by going to particular row no. and column
StarWars.iloc[10,34]
# Out:
# '500'

# %%
#replacing that value with the most occuring value in the column
StarWars.iloc[10,34] = '45-60'

# %%
#display of updated age column
StarWars['Age'].iloc[5:15]
# Out:
# 5     18-29
# 6     18-29
# 7     18-29
# 8       NaN
# 9       NaN
# 10    45-60
# 11    30-44
# 12    18-29
# 13    18-29
# 14    18-29
# Name: Age, dtype: object

# %%
#displaying updated starwars columns after removing typos,white spaces and impossible values

for c in df.columns:
    print ("---- %s ---" % c)
    print (df[c].value_counts())
# Out:
# ---- Respondant ID ---
# 3289370623    1
# 3290063543    1
# 3289539921    1
# 3290206907    1
# 3291022013    1
#              ..
# 3289481310    1
# 3290944858    1
# 3288653149    1
# 3290428766    1
# 3289878528    1
# Name: Respondant ID, Length: 1184, dtype: int64
# ---- seen_any_of_6films ---
# YES    935
# NO     249
# Name: seen_any_of_6films, dtype: int64
# ---- fan? ---
# YES    551
# NO     284
# Name: fan?, dtype: int64
# ---- Episode_1 ---
# STAR WARS: EPISODE I  THE PHANTOM MENACE    672
# Name: Episode_1, dtype: int64
# ---- Episode_2 ---
# STAR WARS: EPISODE II  ATTACK OF THE CLONES    570
# Name: Episode_2, dtype: int64
# ---- Episode_3 ---
# STAR WARS: EPISODE III  REVENGE OF THE SITH    549
# Name: Episode_3, dtype: int64
# ---- Episode_4 ---
# STAR WARS: EPISODE IV  A NEW HOPE    606
# Name: Episode_4, dtype: int64
# ---- Episode_5 ---
# STAR WARS: EPISODE V THE EMPIRE STRIKES BACK    757
# Name: Episode_5, dtype: int64
# ---- Episode_6 ---
# STAR WARS: EPISODE VI RETURN OF THE JEDI    737
# Name: Episode_6, dtype: int64
# ---- rank_1 ---
# 4.0    237
# 6.0    168
# 3.0    129
# 1.0    129
# 5.0    100
# 2.0     71
# Name: rank_1, dtype: int64
# ---- rank_2 ---
# 5.0    300
# 4.0    183
# 2.0    115
# 3.0    103
# 6.0    102
# 1.0     32
# Name: rank_2, dtype: int64
# ---- rank_3 ---
# 6.0    217
# 5.0    203
# 4.0    182
# 3.0    150
# 2.0     47
# 1.0     35
# Name: rank_3, dtype: int64
# ---- rank_4 ---
# 1.0    204
# 6.0    161
# 2.0    135
# 4.0    129
# 3.0    127
# 5.0     79
# Name: rank_4, dtype: int64
# ---- rank_5 ---
# 1.0    289
# 2.0    235
# 5.0    117
# 3.0    106
# 4.0     47
# 6.0     41
# Name: rank_5, dtype: int64
# ---- rank_6 ---
# 2.0    232
# 3.0    220
# 1.0    146
# 6.0    144
# 4.0     57
# 5.0     36
# Name: rank_6, dtype: int64
# ---- Han Solo favored? ---
# VERY FAVORABLY                                 609
# SOMEWHAT FAVORABLY                             151
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     44
# UNFAMILIAR (N/A)                                15
# SOMEWHAT UNFAVORABLY                             8
# VERY UNFAVORABLY                                 1
# Name: Han Solo favored?, dtype: int64
# ---- Luke Skywalker favored? ---
# VERY FAVORABLY                                 551
# SOMEWHAT FAVORABLY                             219
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     38
# SOMEWHAT UNFAVORABLY                            13
# UNFAMILIAR (N/A)                                 6
# VERY UNFAVORABLY                                 3
# Name: Luke Skywalker favored?, dtype: int64
# ---- Princess Leia Organa favored? ---
# VERY FAVORABLY                                 546
# SOMEWHAT FAVORABLY                             210
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     48
# SOMEWHAT UNFAVORABLY                            12
# UNFAMILIAR (N/A)                                 8
# VERY UNFAVORABLY                                 6
# Name: Princess Leia Organa favored?, dtype: int64
# ---- Anakin Skywalker favored? ---
# SOMEWHAT FAVORABLY                             269
# VERY FAVORABLY                                 244
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)    135
# SOMEWHAT UNFAVORABLY                            83
# UNFAMILIAR (N/A)                                52
# VERY UNFAVORABLY                                39
# Name: Anakin Skywalker favored?, dtype: int64
# ---- Obi Wan Kenobi favored? ---
# VERY FAVORABLY                                 590
# SOMEWHAT FAVORABLY                             159
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     43
# UNFAMILIAR (N/A)                                17
# SOMEWHAT UNFAVORABLY                             8
# VERY UNFAVORABLY                                 7
# Name: Obi Wan Kenobi favored?, dtype: int64
# ---- Emperor Palpatine favored? ---
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)    213
# UNFAMILIAR (N/A)                               156
# SOMEWHAT FAVORABLY                             143
# VERY UNFAVORABLY                               124
# VERY FAVORABLY                                 109
# SOMEWHAT UNFAVORABLY                            68
# Name: Emperor Palpatine favored?, dtype: int64
# ---- Darth Vader favored? ---
# VERY FAVORABLY                                 309
# SOMEWHAT FAVORABLY                             171
# VERY UNFAVORABLY                               149
# SOMEWHAT UNFAVORABLY                           102
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     84
# UNFAMILIAR (N/A)                                10
# Name: Darth Vader favored?, dtype: int64
# ---- Lando Calrissian favored? ---
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)    236
# SOMEWHAT FAVORABLY                             223
# UNFAMILIAR (N/A)                               147
# VERY FAVORABLY                                 142
# SOMEWHAT UNFAVORABLY                            63
# VERY UNFAVORABLY                                 8
# Name: Lando Calrissian favored?, dtype: int64
# ---- Boba Fett favored? ---
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)    248
# SOMEWHAT FAVORABLY                             153
# VERY FAVORABLY                                 138
# UNFAMILIAR (N/A)                               131
# SOMEWHAT UNFAVORABLY                            96
# VERY UNFAVORABLY                                45
# Name: Boba Fett favored?, dtype: int64
# ---- C-3P0 favored? ---
# VERY FAVORABLY                                 473
# SOMEWHAT FAVORABLY                             229
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     79
# SOMEWHAT UNFAVORABLY                            23
# UNFAMILIAR (N/A)                                15
# VERY UNFAVORABLY                                 7
# Name: C-3P0 favored?, dtype: int64
# ---- R2 D2 favored? ---
# VERY FAVORABLY                                 561
# SOMEWHAT FAVORABLY                             185
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     57
# SOMEWHAT UNFAVORABLY                            10
# UNFAMILIAR (N/A)                                10
# VERY UNFAVORABLY                                 6
# Name: R2 D2 favored?, dtype: int64
# ---- Jar Jar Binks favored? ---
# VERY UNFAVORABLY                               204
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)    164
# SOMEWHAT FAVORABLY                             130
# VERY FAVORABLY                                 111
# UNFAMILIAR (N/A)                               109
# SOMEWHAT UNFAVORABLY                           102
# Name: Jar Jar Binks favored?, dtype: int64
# ---- Padme Amidala favored? ---
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)    207
# SOMEWHAT FAVORABLY                             183
# VERY FAVORABLY                                 167
# UNFAMILIAR (N/A)                               164
# SOMEWHAT UNFAVORABLY                            58
# VERY UNFAVORABLY                                34
# Name: Padme Amidala favored?, dtype: int64
# ---- Yoda favored? ---
# VERY FAVORABLY                                 604
# SOMEWHAT FAVORABLY                             144
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     51
# UNFAMILIAR (N/A)                                10
# SOMEWHAT UNFAVORABLY                             8
# VERY UNFAVORABLY                                 8
# Name: Yoda favored?, dtype: int64
# ---- shoted_first ---
# HAN                                 325
# I DON'T UNDERSTAND THIS QUESTION    305
# GREEDO                              197
# Name: shoted_first, dtype: int64
# ---- familiar_with_the_Expanded_Universe? ---
# No     615
# Yes    212
# Name: familiar_with_the_Expanded_Universe?, dtype: int64
# ---- fan of the_Expanded_Universe? ---
# NO     113
# YES     99
# Name: fan of the_Expanded_Universe?, dtype: int64
# ---- fan of star_treck? ---
# NO     640
# YES    426
# Name: fan of star_treck?, dtype: int64
# ---- Gender ---
# FEMALE    549
# MALE      495
# Name: Gender, dtype: int64
# ---- Age ---
# 45-60    292
# > 60     269
# 30-44    268
# 18-29    215
# Name: Age, dtype: int64
# ---- Income ---
# $50,000 - $99,999      298
# $25,000 - $49,999      186
# $100,000 - $149,999    141
# $0 - $24,999           137
# $150,000+               95
# Name: Income, dtype: int64
# ---- Education ---
# SOME COLLEGE OR ASSOCIATE DEGREE    328
# BACHELOR DEGREE                     320
# GRADUATE DEGREE                     275
# HIGH SCHOOL DEGREE                  104
# LESS THAN HIGH SCHOOL DEGREE          7
# Name: Education, dtype: int64
# ---- Location ---
# EAST NORTH CENTRAL    181
# PACIFIC               175
# SOUTH ATLANTIC        169
# MIDDLE ATLANTIC       122
# WEST SOUTH CENTRAL    109
# WEST NORTH CENTRAL     93
# MOUNTAIN               79
# NEW ENGLAND            75
# EAST SOUTH CENTRAL     38
# Name: Location, dtype: int64

# %%
#checking for any null values
StarWars['fan?'].isnull().value_counts()
# Out:
# False    835
# True     349
# Name: fan?, dtype: int64

# %%
#checking for any null values
StarWars['familiar_with_the_Expanded_Universe?'].isnull().value_counts()
# Out:
# False    827
# True     357
# Name: familiar_with_the_Expanded_Universe?, dtype: int64

# %%
#checking for any null values
StarWars['Han Solo favored?'].isnull().value_counts()
# Out:
# False    828
# True     356
# Name: Han Solo favored?, dtype: int64

# %%
#checking for any null values
StarWars['Luke Skywalker favored?'].isnull().value_counts()
# Out:
# False    830
# True     354
# Name: Luke Skywalker favored?, dtype: int64

# %%
#checking for any null values
StarWars['Princess Leia Organa favored?'].isnull().value_counts()
# Out:
# False    830
# True     354
# Name: Princess Leia Organa favored?, dtype: int64

# %%
#checking for any null values
StarWars['Anakin Skywalker favored?'].isnull().value_counts()
# Out:
# False    822
# True     362
# Name: Anakin Skywalker favored?, dtype: int64

# %%
#checking for any null values
StarWars['Obi Wan Kenobi favored?'].isnull().value_counts()
# Out:
# False    824
# True     360
# Name: Obi Wan Kenobi favored?, dtype: int64

# %%
#checking for any null values
StarWars['Emperor Palpatine favored?'].isnull().value_counts()
# Out:
# False    813
# True     371
# Name: Emperor Palpatine favored?, dtype: int64

# %%
#checking for any null values
StarWars['Darth Vader favored?'].isnull().value_counts()
# Out:
# False    825
# True     359
# Name: Darth Vader favored?, dtype: int64

# %%
#checking for any null values
StarWars['Lando Calrissian favored?'].isnull().value_counts()
# Out:
# False    819
# True     365
# Name: Lando Calrissian favored?, dtype: int64

# %%
#checking for any null values
StarWars['Boba Fett favored?'].isnull().value_counts()
# Out:
# False    811
# True     373
# Name: Boba Fett favored?, dtype: int64

# %%
#checking for any null values
StarWars['C-3P0 favored?'].isnull().value_counts()
# Out:
# False    826
# True     358
# Name: C-3P0 favored?, dtype: int64

# %%
#checking for any null values
StarWars['R2 D2 favored?'].isnull().value_counts()
# Out:
# False    829
# True     355
# Name: R2 D2 favored?, dtype: int64

# %%
#checking for any null values
StarWars['Jar Jar Binks favored?'].isnull().value_counts()
# Out:
# False    820
# True     364
# Name: Jar Jar Binks favored?, dtype: int64

# %%
#checking for any null values
StarWars['Padme Amidala favored?'].isnull().value_counts()
# Out:
# False    813
# True     371
# Name: Padme Amidala favored?, dtype: int64

# %%
#checking for any null values
StarWars['Yoda favored?'].isnull().value_counts()
# Out:
# False    825
# True     359
# Name: Yoda favored?, dtype: int64

# %%
#checking for any null values
StarWars['fan of star_treck?'].isnull().value_counts()
# Out:
# False    1066
# True      118
# Name: fan of star_treck?, dtype: int64

# %%
#counting no. of 'NO' in the column
a=StarWars['fan of star_treck?']=='YES'
a.value_counts()
# Out:
# False    758
# True     426
# Name: fan of star_treck?, dtype: int64

# %%
#checking for any null values
StarWars['Gender'].isnull().value_counts()
# Out:
# False    1044
# True      140
# Name: Gender, dtype: int64

# %%
#counting no. of 'FEMALE' in column
a=StarWars['Gender']=='FEMALE'
a.value_counts()
# Out:
# False    635
# True     549
# Name: Gender, dtype: int64

# %%
#counting no. of 'FEMALE' in column
a=StarWars['Gender']=='MALE'
a.value_counts()
# Out:
# False    689
# True     495
# Name: Gender, dtype: int64

# %%
#checking for any null values
StarWars['Income'].isnull().value_counts()
# Out:
# False    857
# True     327
# Name: Income, dtype: int64

# %%
#checking for any null values
StarWars['Education'].isnull().value_counts()
# Out:
# False    1034
# True      150
# Name: Education, dtype: int64

# %%
#checking for any null values
StarWars['Location'].isnull().value_counts()
# Out:
# False    1041
# True      143
# Name: Location, dtype: int64

# %%
#checking for any null values
StarWars['Age'].isnull().value_counts()
# Out:
# False    1044
# True      140
# Name: Age, dtype: int64

# %%
#checking for any null values
StarWars['Episode_1'].isnull().value_counts()
# Out:
# False    672
# True     512
# Name: Episode_1, dtype: int64

# %%
#checking for any null values
StarWars['Episode_2'].isnull().value_counts()
# Out:
# True     614
# False    570
# Name: Episode_2, dtype: int64

# %%
#checking for any null values
StarWars['Episode_3'].isnull().value_counts()
# Out:
# True     635
# False    549
# Name: Episode_3, dtype: int64

# %%
#checking for any null values
StarWars['Episode_4'].isnull().value_counts()
# Out:
# False    606
# True     578
# Name: Episode_4, dtype: int64

# %%
#checking for any null values
StarWars['Episode_5'].isnull().value_counts()
# Out:
# False    757
# True     427
# Name: Episode_5, dtype: int64

# %%
#checking for any null values
StarWars['Episode_6'].isnull().value_counts()
# Out:
# False    737
# True     447
# Name: Episode_6, dtype: int64

# %%
#filling na values in the column 'fan of star_treck?' with the most occuring value whilst ignoring other observations having missing values
StarWars['fan of star_treck?']=StarWars['fan of star_treck?'].fillna('NO')

# %%
#display updated starwars file
StarWars
# Out:
#       Respondant ID seen_any_of_6films fan?  \
# 0        3292765271                YES   NO
# 1        3292763116                YES  YES
# 2        3292731220                YES  YES
# 3        3292719380                YES  YES
# 4        3292684787                YES  YES
# ...             ...                ...  ...
# 1179     3288388730                YES  YES
# 1180     3288378779                YES  YES
# 1181     3288375286                 NO  NaN
# 1182     3288373068                YES  YES
# 1183     3288372923                YES   NO
#
#                                      Episode_1  \
# 0     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 2     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 3     STAR WARS: EPISODE I  THE PHANTOM MENACE
# 4     STAR WARS: EPISODE I  THE PHANTOM MENACE
# ...                                        ...
# 1179  STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1180  STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1181                                       NaN
# 1182  STAR WARS: EPISODE I  THE PHANTOM MENACE
# 1183  STAR WARS: EPISODE I  THE PHANTOM MENACE
#
#                                         Episode_2  \
# 0     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 2     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 3     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 4     STAR WARS: EPISODE II  ATTACK OF THE CLONES
# ...                                           ...
# 1179  STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1180  STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1181                                          NaN
# 1182  STAR WARS: EPISODE II  ATTACK OF THE CLONES
# 1183  STAR WARS: EPISODE II  ATTACK OF THE CLONES
#
#                                         Episode_3  \
# 0     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 2     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 3     STAR WARS: EPISODE III  REVENGE OF THE SITH
# 4     STAR WARS: EPISODE III  REVENGE OF THE SITH
# ...                                           ...
# 1179  STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1180  STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1181                                          NaN
# 1182  STAR WARS: EPISODE III  REVENGE OF THE SITH
# 1183                                          NaN
#
#                               Episode_4  \
# 0                                   NaN
# 1     STAR WARS: EPISODE IV  A NEW HOPE
# 2     STAR WARS: EPISODE IV  A NEW HOPE
# 3     STAR WARS: EPISODE IV  A NEW HOPE
# 4     STAR WARS: EPISODE IV  A NEW HOPE
# ...                                 ...
# 1179  STAR WARS: EPISODE IV  A NEW HOPE
# 1180  STAR WARS: EPISODE IV  A NEW HOPE
# 1181                                NaN
# 1182  STAR WARS: EPISODE IV  A NEW HOPE
# 1183                                NaN
#
#                                          Episode_5  \
# 0                                              NaN
# 1     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 2     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 3     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 4     STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# ...                                            ...
# 1179  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 1180  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 1181                                           NaN
# 1182  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
# 1183  STAR WARS: EPISODE V THE EMPIRE STRIKES BACK
#
#                                      Episode_6  rank_1  ...  \
# 0                                          NaN     1.0  ...
# 1     STAR WARS: EPISODE VI RETURN OF THE JEDI     5.0  ...
# 2     STAR WARS: EPISODE VI RETURN OF THE JEDI     5.0  ...
# 3     STAR WARS: EPISODE VI RETURN OF THE JEDI     1.0  ...
# 4     STAR WARS: EPISODE VI RETURN OF THE JEDI     6.0  ...
# ...                                        ...     ...  ...
# 1179  STAR WARS: EPISODE VI RETURN OF THE JEDI     5.0  ...
# 1180  STAR WARS: EPISODE VI RETURN OF THE JEDI     4.0  ...
# 1181                                       NaN     NaN  ...
# 1182  STAR WARS: EPISODE VI RETURN OF THE JEDI     4.0  ...
# 1183  STAR WARS: EPISODE VI RETURN OF THE JEDI     6.0  ...
#
#            Yoda favored?                      shoted_first  \
# 0       UNFAMILIAR (N/A)  I DON'T UNDERSTAND THIS QUESTION
# 1         VERY FAVORABLY  I DON'T UNDERSTAND THIS QUESTION
# 2     SOMEWHAT FAVORABLY                            GREEDO
# 3         VERY FAVORABLY                               HAN
# 4         VERY FAVORABLY                               HAN
# ...                  ...                               ...
# 1179      VERY FAVORABLY                               HAN
# 1180      VERY FAVORABLY  I DON'T UNDERSTAND THIS QUESTION
# 1181                 NaN                               NaN
# 1182      VERY FAVORABLY                               HAN
# 1183    VERY UNFAVORABLY  I DON'T UNDERSTAND THIS QUESTION
#
#       familiar_with_the_Expanded_Universe?  fan of the_Expanded_Universe?  \
# 0                                       No                            NaN
# 1                                       No                            NaN
# 2                                      Yes                             NO
# 3                                      Yes                             NO
# 4                                      Yes                             NO
# ...                                    ...                            ...
# 1179                                    No                            NaN
# 1180                                    No                            NaN
# 1181                                   NaN                            NaN
# 1182                                    No                            NaN
# 1183                                    No                            NaN
#
#       fan of star_treck?  Gender    Age               Income  \
# 0                     NO    MALE  18-29         $0 - $24,999
# 1                    YES    MALE  18-29  $100,000 - $149,999
# 2                     NO    MALE  18-29  $100,000 - $149,999
# 3                    YES    MALE  18-29    $25,000 - $49,999
# 4                     NO    MALE  18-29                  NaN
# ...                  ...     ...    ...                  ...
# 1179                 YES  FEMALE  18-29         $0 - $24,999
# 1180                 YES  FEMALE  30-44    $50,000 - $99,999
# 1181                  NO  FEMALE  30-44    $50,000 - $99,999
# 1182                 YES  FEMALE  45-60  $100,000 - $149,999
# 1183                  NO  FEMALE   > 60    $50,000 - $99,999
#
#                              Education            Location
# 0                   HIGH SCHOOL DEGREE  WEST NORTH CENTRAL
# 1     SOME COLLEGE OR ASSOCIATE DEGREE  WEST NORTH CENTRAL
# 2     SOME COLLEGE OR ASSOCIATE DEGREE  WEST NORTH CENTRAL
# 3                      BACHELOR DEGREE     MIDDLE ATLANTIC
# 4                   HIGH SCHOOL DEGREE  EAST NORTH CENTRAL
# ...                                ...                 ...
# 1179  SOME COLLEGE OR ASSOCIATE DEGREE  EAST NORTH CENTRAL
# 1180                   BACHELOR DEGREE            MOUNTAIN
# 1181                   BACHELOR DEGREE     MIDDLE ATLANTIC
# 1182  SOME COLLEGE OR ASSOCIATE DEGREE  EAST NORTH CENTRAL
# 1183                   GRADUATE DEGREE             PACIFIC
#
# [1184 rows x 38 columns]

# %%
#question 2.1
# plotting pie chart of how episodes from 1 to 6 are ranked

plt.figure(0)
StarWars['rank_1'].value_counts().plot.pie(autopct='%.2f')
plt.figure(1) 
StarWars['rank_2'].value_counts().plot.pie(autopct='%.2f')
plt.figure(3)
StarWars['rank_3'].value_counts().plot.pie(autopct='%.2f')
plt.figure(4)   
StarWars['rank_4'].value_counts().plot.pie(autopct='%.2f')
plt.show()
StarWars['rank_5'].value_counts().plot.pie(autopct='%.2f')
plt.show() 
StarWars['rank_6'].value_counts().plot.pie(autopct='%.2f')
plt.show()

# %%
#plotting bar graph to see how many female/male have given rank 1 for episode 6
sw_f=StarWars['rank_6']==1
rank6_g=StarWars.loc[sw_f,'Gender'].value_counts()
f=rank6_g.plot(kind='bar')
f.grid()
rank6_g
# Out:
# FEMALE    77
# MALE      67
# Name: Gender, dtype: int64

# %%
#plotting bar graph to see how many female/male have given rank 1 for episode 5
sw_f=StarWars['rank_5']==1
rank5_g=StarWars.loc[sw_f,'Gender'].value_counts()
f=rank5_g.plot(kind='bar')
f.grid()
rank5_g
# Out:
# MALE      152
# FEMALE    131
# Name: Gender, dtype: int64

# %%
#plotting bar graph to see how many female/male have given rank 1 for episode 4
sw_f=StarWars['rank_4']==1
rank4_g=StarWars.loc[sw_f,'Gender'].value_counts()
f=rank4_g.plot(kind='bar')
f.grid()
rank4_g
# Out:
# MALE      112
# FEMALE     90
# Name: Gender, dtype: int64

# %%
#plotting pie chart to see how different age groups has given rank 1 for episode 6

swf1=StarWars['rank_6']==1.0
countf1=StarWars.loc[swf1,'Age'].value_counts()
A=countf1.plot(kind='pie', autopct='%.2f')
A.grid()
countf1
# Out:
# 30-44    48
# 45-60    34
# 18-29    32
# > 60     30
# Name: Age, dtype: int64

# %%
#plotting pie chart to see how different age groups has given rank 1 for episode 5

swf1=StarWars['rank_5']==1.0
countf1=StarWars.loc[swf1,'Age'].value_counts()
A=countf1.plot(kind='pie', autopct='%.2f')
A.grid()
countf1
# Out:
# 45-60    90
# 30-44    78
# > 60     60
# 18-29    55
# Name: Age, dtype: int64

# %%
#plotting pie chart to see how different age groups has given rank 1 for episode 4

swf1=StarWars['rank_4']==1.0
countf1=StarWars.loc[swf1,'Age'].value_counts()
A=countf1.plot(kind='pie', autopct='%.2f')
A.grid()
countf1
# Out:
# 45-60    70
# 30-44    56
# > 60     38
# 18-29    38
# Name: Age, dtype: int64

# %%
#plotting bar graph to see where people are based who have given rating 1 for episode 5(liked the most by seeing above pie chart)

swf1=StarWars['rank_5']==1.0
countf1=StarWars.loc[swf1,'Location'].value_counts()
A=countf1.plot(kind='bar')
A.grid()
countf1
# Out:
# SOUTH ATLANTIC        53
# EAST NORTH CENTRAL    49
# PACIFIC               45
# MIDDLE ATLANTIC       30
# WEST NORTH CENTRAL    29
# WEST SOUTH CENTRAL    24
# NEW ENGLAND           23
# MOUNTAIN              18
# EAST SOUTH CENTRAL    12
# Name: Location, dtype: int64

# %%
# question 2.2
#plotting bar graph to see those who have seen any of 6 films of 'starwars franchise' is a 'starwar franchise' fan or not

swf1=StarWars['seen_any_of_6films']=='YES'
countf1=StarWars.loc[swf1,'fan?'].value_counts()
a=countf1.plot(kind='bar')
a.grid()
countf1
# Out:
# YES    551
# NO     284
# Name: fan?, dtype: int64

# %%
#plot bar graph to see people who are star treck fan are fan of Expanded_Universe as well?

swf1=StarWars['fan of star_treck?']=='YES'
countf1=StarWars.loc[swf1,'fan of the_Expanded_Universe?'].value_counts()
A=countf1.plot(kind='bar',color='orange')
A.grid()
countf1
# Out:
# YES    72
# NO     69
# Name: fan of the_Expanded_Universe?, dtype: int64

# %%
#plot pie chart to see if star war fans are familiar with the Expanded Universe?

swf1=StarWars['fan?']=='YES'
countf1=StarWars.loc[swf1,'familiar_with_the_Expanded_Universe?'].value_counts()
A=countf1.plot(kind='bar',color='red')
A.grid()
countf1
# Out:
# No     360
# Yes    184
# Name: familiar_with_the_Expanded_Universe?, dtype: int64

# %%
swf1=StarWars['Gender']=='FEMALE'
countf1=StarWars.loc[swf1,'Han Solo favored?'].value_counts()
A=countf1.plot(kind='bar',color='red')
A.grid()
countf1
# Out:
# VERY FAVORABLY                                 289
# SOMEWHAT FAVORABLY                              71
# NEITHER FAVORABLY NOR UNFAVORABLY (NEUTRAL)     22
# UNFAMILIAR (N/A)                                 9
# SOMEWHAT UNFAVORABLY                             3
# Name: Han Solo favored?, dtype: int64

# %%
#ques 2.3
#plotting graph for how much a character is favorable based on gender
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Han Solo favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')
# Out:
# E:\RMIT\PYTHON\software\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Luke Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Princess Leia Organa favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Anakin Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Obi Wan Kenobi favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Emperor Palpatine favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Darth Vader favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Lando Calrissian favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Boba Fett favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("C-3P0 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("R2 D2 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Jar Jar Binks favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Padme Amidala favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on gender

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Yoda favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Gender')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Han Solo favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Luke Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Princess Leia Organa favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Anakin Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Obi Wan Kenobi favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Emperor Palpatine favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Darth Vader favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Lando Calrissian favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Boba Fett favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("C-3P0 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("R2 D2 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Jar Jar Binks favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Padme Amidala favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph for how much a character is favorable based on Age
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Yoda favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Age')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Han Solo favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Luke Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Princess Leia Organa favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Anakin Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Obi Wan Kenobi favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Emperor Palpatine favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Darth Vader favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Lando Calrissian favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Boba Fett favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("C-3P0 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("R2 D2 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Jar Jar Binks favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Padme Amidala favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if income has any relation with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Yoda favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Income')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Han Solo favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Luke Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Princess Leia Organa favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Anakin Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Obi Wan Kenobi favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Emperor Palpatine favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Darth Vader favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Lando Calrissian favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Boba Fett favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("C-3P0 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("R2 D2 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Jar Jar Binks favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Padme Amidala favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to find if Education is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Yoda favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Education')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability
with sns.axes_style('whitegrid'):
    g = sns.factorplot("Han Solo favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Luke Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Princess Leia Organa favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Anakin Skywalker favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Obi Wan Kenobi favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Emperor Palpatine favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Darth Vader favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Lando Calrissian favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Boba Fett favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("C-3P0 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("R2 D2 favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Jar Jar Binks favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Padme Amidala favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')

# %%
#plotting graph to see if people's location is related with character's favorability

with sns.axes_style('whitegrid'):
    g = sns.factorplot("Yoda favored?", data=StarWars, aspect=4.0, kind='count',
                       hue='Location')
    g.set_ylabels('Number of People')
